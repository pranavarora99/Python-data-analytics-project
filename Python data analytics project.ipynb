# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\Users\prana\Downloads\archive")
# Out:
#   File "<ipython-input-4-7dffeb60e8e8>", line 1
#     df = pd.read_csv("C:\Users\prana\Downloads\archive")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv("\Users\prana\Downloads\archive")
# Out:
#   File "<ipython-input-5-88dc74de57e4>", line 1
#     df = pd.read_csv("\Users\prana\Downloads\archive")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv("Users\prana\Downloads\archive\Amazon_Video_Games.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e1627004dc35> in <module>
# ----> 1 df = pd.read_csv("Users\prana\Downloads\archive\Amazon_Video_Games.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
print("hello world")
# Out:
# hello world

# %%
df = pd.read_csv("C:/Users/prana/Downloads/archive/Air_Conditioners.csv")

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
df.count()
# Out:
# name              720
# main_category     720
# sub_category      720
# image             720
# link              720
# ratings           433
# no_of_ratings     433
# discount_price    457
# actual_price      500
# dtype: int64

# %%
df['actual_price'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e6a7a0f22f47> in <module>
# ----> 1 df['actual_price'].max()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ...

# %%
df['actual_price'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e6a7a0f22f47> in <module>
# ----> 1 df['actual_price'].max()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ...

# %%
df = pd.read_csv("C:/Users/prana/Downloads/archive/players_22.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-04ec2013d70c> in <module>
# ----> 1 df = pd.read_csv("C:/Users/prana/Downloads/archive/players_22.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df = pd.read_csv("C:/Users/prana/Downloads/archive/players_22.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-04ec2013d70c> in <module>
# ----> 1 df = pd.read_csv("C:/Users/prana/Downloads/archive/players_22.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df = pd.read_csv("C:/Users/prana/Downloads/archive/players_22.csv", engine='python')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-23-c86aab5ff777> in <module>
# ----> 1 df = pd.read_csv("C:/Users/prana/Downloads/archive/players_22.csv", engine='python')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df = pd.read_csv("C:/Users/prana/OneDrive/Desktop/Data_engineering/players_22.csv")

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
df["overall"].max()
# Out:
# 93

# %%
df["overall"].min()
# Out:
# 47

# %%
df[df["overall"]==47]
# Out:
#        sofifa_id                                         player_url  \
# 19220     243725  https://sofifa.com/player/243725/darren-collin...
# 19221     243790  https://sofifa.com/player/243790/zhenao-wang/2...
# 19222     245024  https://sofifa.com/player/245024/shilong-wang/...
# 19223     255615  https://sofifa.com/player/255615/xinfeng-fang/...
# 19224     257687  https://sofifa.com/player/257687/xingyu-hu/220002
# 19225     259213  https://sofifa.com/player/259213/dylan-da-silv...
# 19226     259219  https://sofifa.com/player/259219/nestor-dias/2...
# 19227     259646  https://sofifa.com/player/259646/arsh-shaikh/2...
# 19228     259650  https://sofifa.com/player/259650/fardin-ali-mo...
# 19229     259737  https://sofifa.com/player/259737/haobam-singh/...
# 19230     260398  https://sofifa.com/player/260398/nathan-dylan-...
# 19231     261547  https://sofifa.com/player/261547/revanth-by/22...
# 19232     261667  https://sofifa.com/player/261667/matthew-obrie...
# ...

# %%
df[df["overall"] > 90]
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5     200389  https://sofifa.com/player/200389/jan-oblak/220002
# 6     231747  https://sofifa.com/player/231747/kylian-mbappe...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
# ...

# %%
df['player_positions']
# Out:
# 0        RW, ST, CF
# 1                ST
# 2            ST, LW
# 3           LW, CAM
# 4           CM, CAM
#             ...
# 19234           CDM
# 19235            CM
# 19236            CM
# 19237            ST
# 19238           CAM
# Name: player_positions, Length: 19239, dtype: object

# %%
list(df['short_name'])[25]
# Out:
# 'R. Lukaku'

# %%
list(df['short_name'])[25].upper()
# Out:
# 'R. LUKAKU'

# %%
df['player_attribute'] = df['player_positions'].str[0:2]

# %%
df['player_attribute']
# Out:
# 0        RW
# 1        ST
# 2        ST
# 3        LW
# 4        CM
#          ..
# 19234    CD
# 19235    CM
# 19236    CM
# 19237    ST
# 19238    CA
# Name: player_attribute, Length: 19239, dtype: object

# %%
df.sort_values(by=['wage_eur'], ascending = False)
# Out:
#        sofifa_id                                         player_url  \
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 11        165153  https://sofifa.com/player/165153/karim-benzema...
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 14        200145  https://sofifa.com/player/200145/carlos-henriq...
# 24        182521  https://sofifa.com/player/182521/toni-kroos/22...
# ...          ...                                                ...
# 12269     183122  https://sofifa.com/player/183122/birkir-mar-sa...
# 12891     245685  https://sofifa.com/player/245685/onni-valakari...
# 14199     259680  https://sofifa.com/player/259680/marko-stameni...
# 14466     213094  https://sofifa.com/player/213094/storm-roux/22...
# 14654     241475  https://sofifa.com/player/241475/pyry-soiri/22...
#
#          short_name                          long_name player_positions  \
# 4      K. De Bruyne                    Kevin De Bruyne          CM, CAM
# ...

# %%
df["wage_to_val_ratio"] = df['wage_eur']/df['value_eur']

# %%
df1 = df[['short_name', 'overall', 'wage_to_val_ratio', 'wage_eur', 'value_eur']]

# %%
df1.head()
# Out:
#           short_name  overall  wage_to_val_ratio  wage_eur    value_eur
# 0           L. Messi       93           0.004103  320000.0   78000000.0
# 1     R. Lewandowski       92           0.002259  270000.0  119500000.0
# 2  Cristiano Ronaldo       91           0.006000  270000.0   45000000.0
# 3          Neymar Jr       91           0.002093  270000.0  129000000.0
# 4       K. De Bruyne       91           0.002789  350000.0  125500000.0
